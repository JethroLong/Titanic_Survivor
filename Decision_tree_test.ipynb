# %%
import pandas as pd
import numpy as np
# from sklearn.ensemble import DecisionTreeClassifier
from sklearn.tree import export_graphviz, DecisionTreeClassifier
from sklearn import tree

# import processed data
train_X = pd.read_csv('/Users/jethrolong/Desktop/train_v2.csv').drop(['Survived'], axis=1).to_numpy()
train_y = pd.read_csv('/Users/jethrolong/Desktop/train_v2.csv')['Survived'].to_numpy()
test_X = pd.read_csv('/Users/jethrolong/Desktop/test_v2.csv').to_numpy()

# Build Model
decision_tree = DecisionTreeClassifier() 
decision_tree.fit(train_X, train_y)  
Y_pred = decision_tree.predict(test_X)  
acc_decision_tree = round(decision_tree.score(train_X, train_y) * 100, 2)
print('{}%'.format(acc_decision_tree))
# Out:
# 87.77%

# %%
train_X = pd.read_csv('/Users/jethrolong/Desktop/train_v2.csv').drop(['Survived'], axis=1).to_numpy()
train_y = pd.read_csv('/Users/jethrolong/Desktop/train_v2.csv')['Survived'].to_numpy()
# train_y = np.expand_dims(train_y, axis=1)

test_X = pd.read_csv('/Users/jethrolong/Desktop/test_v2.csv').to_numpy()

test_data = pd.read_csv('/Users/jethrolong/Desktop/test_v2.csv')
train_data = pd.read_csv('/Users/jethrolong/Desktop/train_v2.csv')
test_orig = pd.read_csv('/Users/jethrolong/Desktop/test_impute.csv')

# %%
print ("Number of training examples: m_train = " + str(train_X.shape[0]))
print ("train_X shape: " + str(train_X.shape))
print ("train_y shape: " + str(train_y.shape))
print ("Test_X shape: " + str(test_X.shape))
# Out:
# Number of training examples: m_train = 891
# train_X shape: (891, 7)
# train_y shape: (891,)
# Test_X shape: (418, 7)

# %%
test_data
# Out:
#      Pclass  Sex  Age  SibSp  Parch  Fare  Embarked
# 0         3    1    4      0      0     1         3
# 1         3    2    4      1      0     1         1
# 2         2    1    4      0      0     2         3
# 3         3    1    2      0      0     2         1
# 4         3    2    1      1      1     2         1
# 5         3    1    1      0      0     2         1
# 6         3    2    2      0      0     1         3
# 7         2    1    2      1      1     3         1
# 8         3    2    1      0      0     1         2
# 9         3    1    1      2      0     3         1
# 10        3    1    1      0      0     1         1
# 11        1    1    4      0      0     3         1
# 12        1    2    2      1      0     4         1
# 13        2    1    4      1      0     3         1
# 14        1    2    4      1      0     4         1
# 15        2    2    2      1      0     3         2
# 16        2    1    4      0      0     2         3
# ...

# %%
test_X
# Out:
# array([[3, 1, 4, ..., 0, 1, 3],
#        [3, 2, 4, ..., 0, 1, 1],
#        [2, 1, 4, ..., 0, 2, 3],
#        ...,
#        [3, 1, 4, ..., 0, 1, 1],
#        [3, 1, 4, ..., 0, 2, 1],
#        [3, 1, 4, ..., 1, 3, 2]])

# %%
results = pd.DataFrame({"PassengerId": test_data["PassengerId"], "Survived": predictions})
print(results.head())
filename ="/Users/jethrolong/Desktop/NTU summer/EE4483 Aritificial Intelligence and Data mining/Project/dataset/submission_16.csv"
results.to_csv(filename, index=False)

# %%
decision_tree = DecisionTreeClassifier() 
decision_tree.fit(train_X, train_y)  
Y_pred = decision_tree.predict(test_X)  
acc_decision_tree = round(decision_tree.score(train_X, train_y) * 100, 2)
print('{}%'.format(acc_decision_tree))
# Out:
# 87.77%

# %%
result_2 = pd.DataFrame({"PassengerId": test_data["PassengerId"], "Survived": Y_pred})
print(result_2.head())
filename ="/Users/jethrolong/Desktop/NTU summer/EE4483 Aritificial Intelligence and Data mining/Project/dataset/submission_17.csv"
results.to_csv(filename, index=False)

# %%
test_data['Survived'] = Y_pred
test_orig['Survived'] = Y_pred
test_orig
# Out:
#      Pclass     Sex  Age  SibSp  Parch      Fare Embarked  Survived
# 0         3    male   34      0      0    7.8292        Q         0
# 1         3  female   47      1      0    7.0000        S         0
# 2         2    male   62      0      0    9.6875        Q         0
# 3         3    male   27      0      0    8.6625        S         0
# 4         3  female   22      1      1   12.2875        S         1
# 5         3    male   14      0      0    9.2250        S         0
# 6         3  female   30      0      0    7.6292        Q         1
# 7         2    male   26      1      1   29.0000        S         0
# 8         3  female   18      0      0    7.2292        C         1
# 9         3    male   21      2      0   24.1500        S         0
# 10        3    male   17      0      0    7.8958        S         0
# 11        1    male   46      0      0   26.0000        S         0
# 12        1  female   23      1      0   82.2667        S         1
# ...

# %%
# import graphviz
# with open('/Users/jethrolong/Desktop/treeGraph', 'w') as f:
#     data_features_names = ['Pclass','Sex','SibSp','Parch','Fare','Embarked','Age']
#     dot_data=tree.export_graphviz(decision_tree,feature_names=data_features_names,out_file=f)
#     graph = graphviz.Source(dot_data)
#     graph

# %%
# test_X_orig = pd.read_csv('/Users/jethrolong/Desktop/NTU summer/EE4483 Aritificial Intelligence and Data mining/Project/dataset/test.csv')
# test_X_orig['Survived'] = Y_pred
# test_X_orig

# %%
# test_X_orig.to_csv('/Users/jethrolong/Desktop/result_2.csv', index=False)

# %%
test_data.describe()
# Out:
#            Pclass         Sex         Age       SibSp       Parch        Fare  \
# count  418.000000  418.000000  418.000000  418.000000  418.000000  418.000000
# mean     2.265550    1.363636    2.433014    0.447368    0.392344    2.476077
# std      0.841838    0.481622    1.225845    0.896760    0.981429    1.148725
# min      1.000000    1.000000    1.000000    0.000000    0.000000    1.000000
# 25%      1.000000    1.000000    1.000000    0.000000    0.000000    1.000000
# 50%      3.000000    1.000000    2.000000    0.000000    0.000000    2.000000
# 75%      3.000000    2.000000    4.000000    1.000000    0.000000    4.000000
# max      3.000000    2.000000    4.000000    8.000000    9.000000    4.000000
#
#          Embarked    Survived
# count  418.000000  418.000000
# mean     1.464115    0.339713
# std      0.685516    0.474179
# min      1.000000    0.000000
# 25%      1.000000    0.000000
# 50%      1.000000    0.000000
# 75%      2.000000    1.000000
# ...

# %%
from Prep import autolabel
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-84f0a6360c8b> in <module>
# ----> 1 from Prep import autolabel
#
# ModuleNotFoundError: No module named 'Prep'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#Bar plot of survival distribution
plt.figure(figsize=(8,5))

barr = plt.bar( test_data.Survived.value_counts().index,  test_data.Survived.value_counts(), alpha = 0.67, )
plt.title('Distribution of Survival')
# autolabel(barr, plt.gca())
plt.xticks([0,1], ['Dead','Alive'])

plt.ylim((0,650))
barr = plt.gcf()
plt.rcParams["figure.figsize"] = (12,6)

plt.show()

# %%
test_data.Survived.value_counts().index,  test_data.Survived.value_counts()
# Out:
# (Int64Index([0, 1], dtype='int64'), 0    277
#  1    141
#  Name: Survived, dtype: int64)

# %%
alive_subframe = test_data[test_data.Survived == 1]

plt.figure(figsize = (10,7))
plt.bar( test_data['Sex'].value_counts().index,  test_data['Sex'].value_counts(), label = 'alive', color = 'grey', alpha = 0.5 )
plt.bar( alive_subframe['Sex'].value_counts().index,  alive_subframe['Sex'].value_counts(), label = 'Alive', color = 'Blue', alpha = 0.5 )
plt.legend(['Total','Alive'])
plt.title('Gender Survival Aboard the Titanic')
plt.ylabel('Number of Passengers')
plt.xticks([1,2], ['Male','Female'])

plt.show()

# %%
test_data['Sex'].value_counts().index,  test_data['Sex'].value_counts()
# Out:
# (Int64Index([1, 2], dtype='int64'), 1    266
#  2    152
#  Name: Sex, dtype: int64)

# %%
alived_subframe
# Out:
#      Pclass     Sex  Age  SibSp  Parch      Fare Embarked  Survived
# 4         3  female   22      1      1   12.2875        S         1
# 6         3  female   30      0      0    7.6292        Q         1
# 8         3  female   18      0      0    7.2292        C         1
# 12        1  female   23      1      0   82.2667        S         1
# 14        1  female   47      1      0   61.1750        S         1
# 15        2  female   24      1      0   27.7208        C         1
# 20        1    male   55      1      0   59.4000        C         1
# 22        1  female   20      0      0   31.6833        S         1
# 24        1  female   48      1      3  262.3750        C         1
# 26        1  female   22      0      1   61.9792        C         1
# 32        3  female   33      1      2   20.5750        S         1
# 34        1    male   30      1      0   57.7500        C         1
# 43        2  female   30      0      0   13.0000        S         1
# ...

# %%
alived_subframe = test_orig[test_orig.Survived==1]
youth_alive = alived_subframe[alived_subframe['Age'] < 18].round(0)
# plt.figure(figsize=(12, 6))

# plt.bar( youth_alive.value_counts().index,  test_data['Sex'].value_counts(), label = 'alive', color = 'grey', alpha = 0.5 )

# plt.legend(['Total','Alived'])
# plt.title('Youth Survivors')
# plt.xlabel('Age')
# plt.ylabel('Number of Passengers')
# # plt.xticks(['18 below', '18 above'])

# plt.show()
alived_subframe= test_orig[test_orig.Survived==1]
alived_subframe
# Out:
#      Pclass     Sex  Age  SibSp  Parch      Fare Embarked  Survived
# 4         3  female   22      1      1   12.2875        S         1
# 6         3  female   30      0      0    7.6292        Q         1
# 8         3  female   18      0      0    7.2292        C         1
# 12        1  female   23      1      0   82.2667        S         1
# 14        1  female   47      1      0   61.1750        S         1
# 15        2  female   24      1      0   27.7208        C         1
# 20        1    male   55      1      0   59.4000        C         1
# 22        1  female   20      0      0   31.6833        S         1
# 24        1  female   48      1      3  262.3750        C         1
# 26        1  female   22      0      1   61.9792        C         1
# 32        3  female   33      1      2   20.5750        S         1
# 34        1    male   30      1      0   57.7500        C         1
# 43        2  female   30      0      0   13.0000        S         1
# ...

# %%
alived_subframe[alived_subframe['Age'] < 18].shape[0]/141
# Out:
# 0.18439716312056736

# %%
alived_subframe.count()
# Out:
# Pclass      141
# Sex         141
# Age         141
# SibSp       141
# Parch       141
# Fare        141
# Embarked    141
# Survived    141
# dtype: int64

# %%
labels = '18 below', '18 above'
sizes = [18.44, 81.56]
explode = (0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Youth Survivors')

plt.show()

# %%
alived_subframe = test_orig[test_orig.Survived==1]
loner = alived_subframe[(alived_subframe['SibSp'] == 0) & (alived_subframe['Parch'] == 0)].round(0)

labels = 'Alone', 'Not Alone'
sizes = [37.59, 62.41]
explode = (0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Loner Survivors')

plt.show()

# %%
loner.shape[0]
# Out:
# 53

# %%
dead_subframe = test_data[test_data.Survived == 0]

plt.figure(figsize = (10,7))
plt.bar( test_data['Embarked'].value_counts().index,  test_data['Embarked'].value_counts(), label = 'Total', color = 'grey', alpha = 0.5 )
plt.bar( dead_subframe['Embarked'].value_counts().index,  dead_subframe['Embarked'].value_counts(), label = 'Dead', color = 'Blue', alpha = 0.5 )
plt.legend(['Total','Dead'])
plt.title('Death-Port Distribution')
plt.ylabel('Number of Passengers')
plt.xticks([1,2,3], ['S','C', 'Q'])

plt.show()

# %%
dead_subframe = test_data[test_data.Survived == 0]
dead_subframe['Embarked'].value_counts()
# Out:
# 1    201
# 2     54
# 3     22
# Name: Embarked, dtype: int64

# %%
test_data['Embarked'].value_counts()
# Out:
# 1    270
# 2    102
# 3     46
# Name: Embarked, dtype: int64
